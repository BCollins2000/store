# %%
import folium
from folium import FeatureGroup, LayerControl, Map

# Create base map
m = folium.Map(location=[45, -100], zoom_start=4)

# Create two feature groups (layers)
layer1 = FeatureGroup(name='Layer 1')
layer2 = FeatureGroup(name='Layer 2')

# Add some markers or shapes to the layers
folium.Marker([45, -100], popup="Layer 1 Marker").add_to(layer1)
folium.Marker([46, -101], popup="Layer 2 Marker").add_to(layer2)

# Add layers to map
layer1.add_to(m)
layer2.add_to(m)

# Add layer control
folium.LayerControl(collapsed=False).add_to(m)

# Add a custom legend div (initially hidden)
legend_html = """
<div id='legend' style='position: fixed; bottom: 50px; left: 50px; z-index:9999; background-color: white;
 padding: 10px; border:2px solid grey; border-radius:5px; display: none;'>
<b>Legend</b><br>
<span style="color:red;">Red marker:</span> Layer 1<br>
<span style="color:blue;">Blue marker:</span> Layer 2
</div>
<script>
    // Wait until the map is ready
    document.addEventListener("DOMContentLoaded", function () {
        let legend = document.getElementById('legend');

        // You might need to adjust these names to exactly match what's in the layer control
        var checkboxes = document.querySelectorAll('.leaflet-control-layers-selector');

        function updateLegend() {
            let layer1On = checkboxes[0].checked;
            let layer2On = checkboxes[1].checked;

            if (layer1On || layer2On) {
                legend.style.display = 'block';
            } else {
                legend.style.display = 'none';
            }
        }

        checkboxes.forEach(cb => cb.addEventListener('change', updateLegend));
        updateLegend();  // initialize state
    });
</script>
"""

m.get_root().html.add_child(folium.Element(legend_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21921a28028e718541be49065e240310 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&#x27;legend&#x27; style=&#x27;position: fixed; bottom: 50px; left: 50px; z-index:9999; background-color: white;
#  padding: 10px; border:2px solid grey; border-radius:5px; display: none;&#x27;&gt;
# &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
# &lt;span style=&quot;color:red;&quot;&gt;Red marker:&lt;/span&gt; Layer 1&lt;br&gt;
# &lt;span style=&quot;color:blue;&quot;&gt;Blue marker:&lt;/span&gt; Layer 2
# &lt;/div&gt;
# &lt;script&gt;
#     // Wait until the map is ready
#     document.addEventListener(&quot;DOMContentLoaded&quot;, function () {
#         let legend = document.getElementById(&#x27;legend&#x27;);
#
#         // You might need to adjust these names to exactly match what&#x27;s in the layer control
#         var checkboxes = document.querySelectorAll(&#x27;.leaflet-control-layers-selector&#x27;);
#
#         function updateLegend() {
#             let layer1On = checkboxes[0].checked;
#             let layer2On = checkboxes[1].checked;
#
#             if (layer1On || layer2On) {
#                 legend.style.display = &#x27;block&#x27;;
#             } else {
#                 legend.style.display = &#x27;none&#x27;;
#             }
#         }
#
#         checkboxes.forEach(cb =&gt; cb.addEventListener(&#x27;change&#x27;, updateLegend));
#         updateLegend();  // initialize state
#     });
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21921a28028e718541be49065e240310&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21921a28028e718541be49065e240310 = L.map(
#                 &quot;map_21921a28028e718541be49065e240310&quot;,
#                 {
#                     center: [45.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c31bd854eb49a1991b870a1b94f081e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c31bd854eb49a1991b870a1b94f081e5.addTo(map_21921a28028e718541be49065e240310);
#
#
#             var feature_group_5fdbf9c1bfd9639bb4f798b41038ad83 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0aecd6e80759b6421be0a24be25853a4 = L.marker(
#                 [45.0, -100.0],
#                 {
# }
#             ).addTo(feature_group_5fdbf9c1bfd9639bb4f798b41038ad83);
#
#
#         var popup_705d039bf0ea6d2e3e390535cbfae8e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25e1462ca02063e55638c2efaaad6f71 = $(`&lt;div id=&quot;html_25e1462ca02063e55638c2efaaad6f71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Layer 1 Marker&lt;/div&gt;`)[0];
#                 popup_705d039bf0ea6d2e3e390535cbfae8e9.setContent(html_25e1462ca02063e55638c2efaaad6f71);
#
#
#
#         marker_0aecd6e80759b6421be0a24be25853a4.bindPopup(popup_705d039bf0ea6d2e3e390535cbfae8e9)
#         ;
#
#
#
#
#             feature_group_5fdbf9c1bfd9639bb4f798b41038ad83.addTo(map_21921a28028e718541be49065e240310);
#
#
#             var feature_group_d73c307d1e4d3b393dbaf6c81d13468d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_369589b9cc5037e5211752405277dc58 = L.marker(
#                 [46.0, -101.0],
#                 {
# }
#             ).addTo(feature_group_d73c307d1e4d3b393dbaf6c81d13468d);
#
#
#         var popup_b76050e8c263ea452861b4dcf6bd9711 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0da3123ce747c75f16c5ff435e40a98e = $(`&lt;div id=&quot;html_0da3123ce747c75f16c5ff435e40a98e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Layer 2 Marker&lt;/div&gt;`)[0];
#                 popup_b76050e8c263ea452861b4dcf6bd9711.setContent(html_0da3123ce747c75f16c5ff435e40a98e);
#
#
#
#         marker_369589b9cc5037e5211752405277dc58.bindPopup(popup_b76050e8c263ea452861b4dcf6bd9711)
#         ;
#
#
#
#
#             feature_group_d73c307d1e4d3b393dbaf6c81d13468d.addTo(map_21921a28028e718541be49065e240310);
#
#
#             var layer_control_d025a49ab89068097021f3ff0d8b1056_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c31bd854eb49a1991b870a1b94f081e5,
#                 },
#                 overlays :  {
#                     &quot;Layer 1&quot; : feature_group_5fdbf9c1bfd9639bb4f798b41038ad83,
#                     &quot;Layer 2&quot; : feature_group_d73c307d1e4d3b393dbaf6c81d13468d,
#                 },
#             };
#             let layer_control_d025a49ab89068097021f3ff0d8b1056 = L.control.layers(
#                 layer_control_d025a49ab89068097021f3ff0d8b1056_layers.base_layers,
#                 layer_control_d025a49ab89068097021f3ff0d8b1056_layers.overlays,

# %%
import folium
from folium import Map, FeatureGroup, LayerControl, Marker

# Initialize map
m = Map(location=[46, -99], zoom_start=5)

# Create layers
layer1 = FeatureGroup(name="Layer 1")
layer2 = FeatureGroup(name="Layer 2")

# Add content to layers
Marker(location=[46, -99], popup="Marker 1").add_to(layer1)
Marker(location=[46.5, -99.5], popup="Marker 2").add_to(layer2)

# Add layers to map
layer1.add_to(m)
layer2.add_to(m)

# Add layer control
LayerControl(collapsed=False).add_to(m)

# Custom legend HTML
legend_html = """
<div id='customLegend' style="
    position: fixed; 
    bottom: 50px; 
    left: 50px; 
    z-index: 9999; 
    background-color: white;
    border: 2px solid grey;
    border-radius: 5px;
    padding: 10px;
    display: none;">
    <b>Legend</b><br>
    <span style='color:red;'>Red marker:</span> Layer 1<br>
    <span style='color:blue;'>Blue marker:</span> Layer 2
</div>

<script>
function toggleLegend() {
    var legend = document.getElementById('customLegend');
    var checkboxes = document.querySelectorAll('.leaflet-control-layers-selector');
    
    var layer1On = checkboxes[0].checked;
    var layer2On = checkboxes[1].checked;

    if (layer1On || layer2On) {
        legend.style.display = 'block';
    } else {
        legend.style.display = 'none';
    }
}

// Wait a bit for map to load, then bind events
setTimeout(() => {
    var checkboxes = document.querySelectorAll('.leaflet-control-layers-selector');
    checkboxes.forEach(cb => cb.addEventListener('change', toggleLegend));
    toggleLegend(); // initial state
}, 500);
</script>
"""

m.get_root().html.add_child(folium.Element(legend_html))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c23d4acf66506d7a2266ebfe3375e6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&#x27;customLegend&#x27; style=&quot;
#     position: fixed;
#     bottom: 50px;
#     left: 50px;
#     z-index: 9999;
#     background-color: white;
#     border: 2px solid grey;
#     border-radius: 5px;
#     padding: 10px;
#     display: none;&quot;&gt;
#     &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#     &lt;span style=&#x27;color:red;&#x27;&gt;Red marker:&lt;/span&gt; Layer 1&lt;br&gt;
#     &lt;span style=&#x27;color:blue;&#x27;&gt;Blue marker:&lt;/span&gt; Layer 2
# &lt;/div&gt;
#
# &lt;script&gt;
# function toggleLegend() {
#     var legend = document.getElementById(&#x27;customLegend&#x27;);
#     var checkboxes = document.querySelectorAll(&#x27;.leaflet-control-layers-selector&#x27;);
#
#     var layer1On = checkboxes[0].checked;
#     var layer2On = checkboxes[1].checked;
#
#     if (layer1On || layer2On) {
#         legend.style.display = &#x27;block&#x27;;
#     } else {
#         legend.style.display = &#x27;none&#x27;;
#     }
# }
#
# // Wait a bit for map to load, then bind events
# setTimeout(() =&gt; {
#     var checkboxes = document.querySelectorAll(&#x27;.leaflet-control-layers-selector&#x27;);
#     checkboxes.forEach(cb =&gt; cb.addEventListener(&#x27;change&#x27;, toggleLegend));
#     toggleLegend(); // initial state
# }, 500);
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c23d4acf66506d7a2266ebfe3375e6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c23d4acf66506d7a2266ebfe3375e6f = L.map(
#                 &quot;map_6c23d4acf66506d7a2266ebfe3375e6f&quot;,
#                 {
#                     center: [46.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb0153e782b2a375e5e6126eab4b6538 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb0153e782b2a375e5e6126eab4b6538.addTo(map_6c23d4acf66506d7a2266ebfe3375e6f);
#
#
#             var feature_group_663b2dafce055959205b68c38e7b712f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_59d35100ac43b834f412eab14b139821 = L.marker(
#                 [46.0, -99.0],
#                 {
# }
#             ).addTo(feature_group_663b2dafce055959205b68c38e7b712f);
#
#
#         var popup_d208e4c756f87b4e40a93b7bb4e348d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7df85179427123171343f8df8e9dafa5 = $(`&lt;div id=&quot;html_7df85179427123171343f8df8e9dafa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d208e4c756f87b4e40a93b7bb4e348d7.setContent(html_7df85179427123171343f8df8e9dafa5);
#
#
#
#         marker_59d35100ac43b834f412eab14b139821.bindPopup(popup_d208e4c756f87b4e40a93b7bb4e348d7)
#         ;
#
#
#
#
#             feature_group_663b2dafce055959205b68c38e7b712f.addTo(map_6c23d4acf66506d7a2266ebfe3375e6f);
#
#
#             var feature_group_70799a4e16ecb42e059ea9552a0dfee0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a6195c17b552eb76a1276b32b1bb3355 = L.marker(
#                 [46.5, -99.5],
#                 {
# }
#             ).addTo(feature_group_70799a4e16ecb42e059ea9552a0dfee0);
#
#
#         var popup_305e82978019774f940117a082a77c7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dadddc10e6274f602e07974121a88f0a = $(`&lt;div id=&quot;html_dadddc10e6274f602e07974121a88f0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_305e82978019774f940117a082a77c7b.setContent(html_dadddc10e6274f602e07974121a88f0a);
#
#
#
#         marker_a6195c17b552eb76a1276b32b1bb3355.bindPopup(popup_305e82978019774f940117a082a77c7b)
#         ;
#
#
#
#
#             feature_group_70799a4e16ecb42e059ea9552a0dfee0.addTo(map_6c23d4acf66506d7a2266ebfe3375e6f);
#
#
#             var layer_control_8f560f8c7ece170de852c623d8f17cb5_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_cb0153e782b2a375e5e6126eab4b6538,
#                 },
#                 overlays :  {
#                     &quot;Layer 1&quot; : feature_group_663b2dafce055959205b68c38e7b712f,
#                     &quot;Layer 2&quot; : feature_group_70799a4e16ecb42e059ea9552a0dfee0,
#                 },
#             };
#             let layer_control_8f560f8c7ece170de852c623d8f17cb5 = L.control.layers(
#                 layer_control_8f560f8c7ece170de852c623d8f17cb5_layers.base_layers,
#                 layer_control_8f560f8c7ece170de852c623d8f17cb5_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;:

# %%
import folium
from folium import Map, FeatureGroup, LayerControl, Marker

# Create a map
m = Map(location=[46, -99], zoom_start=5)

# Create two layers
layer1 = FeatureGroup(name="Layer 1")
layer2 = FeatureGroup(name="Layer 2")

# Add markers to each layer
Marker([46, -99], popup="Marker in Layer 1").add_to(layer1)
Marker([46.5, -99.5], popup="Marker in Layer 2").add_to(layer2)

# Add the layers to the map
layer1.add_to(m)
layer2.add_to(m)

# Add a layer control
LayerControl(collapsed=False).add_to(m)

# Get the map variable name (e.g., "map_12345") so we can reference it in our JS
map_id = m.get_name()

# Create custom legend HTML and JS.
# The JS attaches to the overlayadd and overlayremove events, so when a layer is toggled,
# it will check all checkboxes in the layer control and show the legend if any are active.
legend_html = f"""
<div id='customLegend' style="
    position: fixed; 
    bottom: 50px; 
    left: 50px; 
    z-index: 9999; 
    background-color: white;
    border: 2px solid grey;
    border-radius: 5px;
    padding: 10px;
    display: none;">
    <b>Legend</b><br>
    <span style='color:red;'>Red marker:</span> Layer 1<br>
    <span style='color:blue;'>Blue marker:</span> Layer 2
</div>

<script>
// Delay execution to ensure the map and layer control are fully loaded
setTimeout(function(){{
    var map = {map_id};
    // Listen for overlay events on the map
    map.on('overlayadd overlayremove', function(e){{
        // Query all layer control checkboxes
        var checkboxes = document.querySelectorAll('.leaflet-control-layers-selector');
        var anyOn = false;
        checkboxes.forEach(function(cb) {{
            if (cb.checked) {{
                anyOn = true;
            }}
        }});
        var legend = document.getElementById('customLegend');
        // Show legend if any overlay is active, otherwise hide it
        legend.style.display = anyOn ? 'block' : 'none';
    }});
}}, 1000);
</script>
"""

# Add the custom legend to the map's HTML
m.get_root().html.add_child(folium.Element(legend_html))

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2ab6f67901ff59fe781331e6861c4df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&#x27;customLegend&#x27; style=&quot;
#     position: fixed;
#     bottom: 50px;
#     left: 50px;
#     z-index: 9999;
#     background-color: white;
#     border: 2px solid grey;
#     border-radius: 5px;
#     padding: 10px;
#     display: none;&quot;&gt;
#     &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#     &lt;span style=&#x27;color:red;&#x27;&gt;Red marker:&lt;/span&gt; Layer 1&lt;br&gt;
#     &lt;span style=&#x27;color:blue;&#x27;&gt;Blue marker:&lt;/span&gt; Layer 2
# &lt;/div&gt;
#
# &lt;script&gt;
# // Delay execution to ensure the map and layer control are fully loaded
# setTimeout(function(){
#     var map = map_d2ab6f67901ff59fe781331e6861c4df;
#     // Listen for overlay events on the map
#     map.on(&#x27;overlayadd overlayremove&#x27;, function(e){
#         // Query all layer control checkboxes
#         var checkboxes = document.querySelectorAll(&#x27;.leaflet-control-layers-selector&#x27;);
#         var anyOn = false;
#         checkboxes.forEach(function(cb) {
#             if (cb.checked) {
#                 anyOn = true;
#             }
#         });
#         var legend = document.getElementById(&#x27;customLegend&#x27;);
#         // Show legend if any overlay is active, otherwise hide it
#         legend.style.display = anyOn ? &#x27;block&#x27; : &#x27;none&#x27;;
#     });
# }, 1000);
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2ab6f67901ff59fe781331e6861c4df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2ab6f67901ff59fe781331e6861c4df = L.map(
#                 &quot;map_d2ab6f67901ff59fe781331e6861c4df&quot;,
#                 {
#                     center: [46.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a8a1eab7505a126290297de3a6e65dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a8a1eab7505a126290297de3a6e65dc.addTo(map_d2ab6f67901ff59fe781331e6861c4df);
#
#
#             var feature_group_442606ac4f5439d306e0449840e1c2ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d0b9444e20e6cf74f77e3e96df166744 = L.marker(
#                 [46.0, -99.0],
#                 {
# }
#             ).addTo(feature_group_442606ac4f5439d306e0449840e1c2ac);
#
#
#         var popup_c1bd2fa3721e674a17f822187044fb7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78e593ebe7e65d1d41bffafe63b65901 = $(`&lt;div id=&quot;html_78e593ebe7e65d1d41bffafe63b65901&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker in Layer 1&lt;/div&gt;`)[0];
#                 popup_c1bd2fa3721e674a17f822187044fb7a.setContent(html_78e593ebe7e65d1d41bffafe63b65901);
#
#
#
#         marker_d0b9444e20e6cf74f77e3e96df166744.bindPopup(popup_c1bd2fa3721e674a17f822187044fb7a)
#         ;
#
#
#
#
#             feature_group_442606ac4f5439d306e0449840e1c2ac.addTo(map_d2ab6f67901ff59fe781331e6861c4df);
#
#
#             var feature_group_daadacf30813a5c02ecc71f1349388f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3045844e5b4944f8cd78c0d2d5efa24d = L.marker(
#                 [46.5, -99.5],
#                 {
# }
#             ).addTo(feature_group_daadacf30813a5c02ecc71f1349388f0);
#
#
#         var popup_c31c75ccb5106f1613f7974955aff8a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a33d9b1d1b2907aaa2c11ec98c1f3537 = $(`&lt;div id=&quot;html_a33d9b1d1b2907aaa2c11ec98c1f3537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker in Layer 2&lt;/div&gt;`)[0];
#                 popup_c31c75ccb5106f1613f7974955aff8a8.setContent(html_a33d9b1d1b2907aaa2c11ec98c1f3537);
#
#
#
#         marker_3045844e5b4944f8cd78c0d2d5efa24d.bindPopup(popup_c31c75ccb5106f1613f7974955aff8a8)
#         ;
#
#
#
#
#             feature_group_daadacf30813a5c02ecc71f1349388f0.addTo(map_d2ab6f67901ff59fe781331e6861c4df);
#
#
#             var layer_control_d392f11da928378ac24be935e3a8fd46_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_0a8a1eab7505a126290297de3a6e65dc,
#                 },
#                 overlays :  {
#                     &quot;Layer 1&quot; : feature_group_442606ac4f5439d306e0449840e1c2ac,
#                     &quot;Layer 2&quot; : feature_group_daadacf30813a5c02ecc71f1349388f0,
#                 },
#             };
#             let layer_control_d392f11da928378ac24be935e3a8fd46 = L.control.layers(
#                 layer_control_d392f11da928378ac24be935e3a8fd46_layers.base_layers,
#                 layer_control_d392f11da928378ac24be935e3a8fd46_layers.overlays,

# %%
import folium
from folium import Map, FeatureGroup, LayerControl, Marker

# Create a basic map
m = Map(location=[46, -99], zoom_start=5)

# Create two layers
layer1 = FeatureGroup(name="Layer 1")
layer2 = FeatureGroup(name="Layer 2")

# Add a marker to each layer
Marker([46, -99], popup="Marker in Layer 1").add_to(layer1)
Marker([46.5, -99.5], popup="Marker in Layer 2").add_to(layer2)

# Add layers to the map
layer1.add_to(m)
layer2.add_to(m)

# Add layer control to the map
LayerControl(collapsed=False).add_to(m)

# Get the map variable name so we can reference it in JavaScript
map_id = m.get_name()

# Custom legend HTML and JavaScript with debugging logs.
legend_html = f"""
<div id='customLegend' style="
    position: fixed; 
    bottom: 50px; 
    left: 50px; 
    z-index: 9999; 
    background-color: white;
    border: 2px solid grey;
    border-radius: 5px;
    padding: 10px;
    display: none;">
    <b>Legend</b><br>
    <span style='color:red;'>Red marker:</span> Layer 1<br>
    <span style='color:blue;'>Blue marker:</span> Layer 2
</div>

<script>
// Function to toggle legend display based on overlay checkboxes
function toggleLegend() {{
    var legend = document.getElementById('customLegend');
    // Select checkboxes in the layer control; if your version of Folium uses a different class, update this selector.
    var checkboxes = document.querySelectorAll('.leaflet-control-layers-selector');
    var anyOn = false;
    checkboxes.forEach(function(cb, index) {{
        console.log("Checkbox " + index + " checked: " + cb.checked);
        if (cb.checked) {{
            anyOn = true;
        }}
    }});
    console.log("Any overlay active: " + anyOn);
    legend.style.display = anyOn ? 'block' : 'none';
}}

// Attach event listeners to checkboxes once they're available.
function attachListeners() {{
    var checkboxes = document.querySelectorAll('.leaflet-control-layers-selector');
    if (checkboxes.length > 0) {{
        console.log("Found " + checkboxes.length + " checkboxes. Attaching listeners.");
        checkboxes.forEach(function(cb) {{
            cb.addEventListener('change', function() {{
                console.log("Checkbox changed");
                toggleLegend();
            }});
        }});
        // Initial toggle check
        toggleLegend();
    }} else {{
        console.log("Checkboxes not found, retrying in 500ms...");
        setTimeout(attachListeners, 500);
    }}
}}

// Start trying to attach listeners after a slight delay to ensure the controls have been rendered.
setTimeout(attachListeners, 1000);
</script>
"""

# Add the legend HTML/JS to the map
m.get_root().html.add_child(folium.Element(legend_html))

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c86967358b298eb5c509e21dda714cd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&#x27;customLegend&#x27; style=&quot;
#     position: fixed;
#     bottom: 50px;
#     left: 50px;
#     z-index: 9999;
#     background-color: white;
#     border: 2px solid grey;
#     border-radius: 5px;
#     padding: 10px;
#     display: none;&quot;&gt;
#     &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
#     &lt;span style=&#x27;color:red;&#x27;&gt;Red marker:&lt;/span&gt; Layer 1&lt;br&gt;
#     &lt;span style=&#x27;color:blue;&#x27;&gt;Blue marker:&lt;/span&gt; Layer 2
# &lt;/div&gt;
#
# &lt;script&gt;
# // Function to toggle legend display based on overlay checkboxes
# function toggleLegend() {
#     var legend = document.getElementById(&#x27;customLegend&#x27;);
#     // Select checkboxes in the layer control; if your version of Folium uses a different class, update this selector.
#     var checkboxes = document.querySelectorAll(&#x27;.leaflet-control-layers-selector&#x27;);
#     var anyOn = false;
#     checkboxes.forEach(function(cb, index) {
#         console.log(&quot;Checkbox &quot; + index + &quot; checked: &quot; + cb.checked);
#         if (cb.checked) {
#             anyOn = true;
#         }
#     });
#     console.log(&quot;Any overlay active: &quot; + anyOn);
#     legend.style.display = anyOn ? &#x27;block&#x27; : &#x27;none&#x27;;
# }
#
# // Attach event listeners to checkboxes once they&#x27;re available.
# function attachListeners() {
#     var checkboxes = document.querySelectorAll(&#x27;.leaflet-control-layers-selector&#x27;);
#     if (checkboxes.length &gt; 0) {
#         console.log(&quot;Found &quot; + checkboxes.length + &quot; checkboxes. Attaching listeners.&quot;);
#         checkboxes.forEach(function(cb) {
#             cb.addEventListener(&#x27;change&#x27;, function() {
#                 console.log(&quot;Checkbox changed&quot;);
#                 toggleLegend();
#             });
#         });
#         // Initial toggle check
#         toggleLegend();
#     } else {
#         console.log(&quot;Checkboxes not found, retrying in 500ms...&quot;);
#         setTimeout(attachListeners, 500);
#     }
# }
#
# // Start trying to attach listeners after a slight delay to ensure the controls have been rendered.
# setTimeout(attachListeners, 1000);
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c86967358b298eb5c509e21dda714cd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c86967358b298eb5c509e21dda714cd9 = L.map(
#                 &quot;map_c86967358b298eb5c509e21dda714cd9&quot;,
#                 {
#                     center: [46.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_213d1d60e86f3e25ce7e7f455e08e1b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_213d1d60e86f3e25ce7e7f455e08e1b0.addTo(map_c86967358b298eb5c509e21dda714cd9);
#
#
#             var feature_group_ac97e4206af91da83e58dd720d352ef7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5594cc1fba8b200577d3bd27d5083d78 = L.marker(
#                 [46.0, -99.0],
#                 {
# }
#             ).addTo(feature_group_ac97e4206af91da83e58dd720d352ef7);
#
#
#         var popup_d71305a892715c1e704ee1d791cf2de5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24eb18543bcb59897e65a12dded51cd8 = $(`&lt;div id=&quot;html_24eb18543bcb59897e65a12dded51cd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker in Layer 1&lt;/div&gt;`)[0];
#                 popup_d71305a892715c1e704ee1d791cf2de5.setContent(html_24eb18543bcb59897e65a12dded51cd8);
#
#
#
#         marker_5594cc1fba8b200577d3bd27d5083d78.bindPopup(popup_d71305a892715c1e704ee1d791cf2de5)
#         ;
#
#
#
#
#             feature_group_ac97e4206af91da83e58dd720d352ef7.addTo(map_c86967358b298eb5c509e21dda714cd9);
#
#
#             var feature_group_a1cf37d197ba1eb7fafeef0408248fef = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5e0a921bcf83f1a987be457e40e9b826 = L.marker(
#                 [46.5, -99.5],
#                 {
# }
#             ).addTo(feature_group_a1cf37d197ba1eb7fafeef0408248fef);
#
#
#         var popup_a0c1296e73c54ac4f4e3168f678b72da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_429211f97ed9071a8456b833742da6be = $(`&lt;div id=&quot;html_429211f97ed9071a8456b833742da6be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker in Layer 2&lt;/div&gt;`)[0];
#                 popup_a0c1296e73c54ac4f4e3168f678b72da.setContent(html_429211f97ed9071a8456b833742da6be);
#
#
#
#         marker_5e0a921bcf83f1a987be457e40e9b826.bindPopup(popup_a0c1296e73c54ac4f4e3168f678b72da)
#         ;

# %%
import folium
from folium.features import DivIcon

m = folium.Map(location=[40, -100], zoom_start=4)

# Simulate tooltips using always-visible text labels
folium.Marker(
    location=[40, -100],
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 12pt; color: red;">Marker 1</div>',
    )
).add_to(m)

folium.Marker(
    location=[41, -101],
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 12pt; color: blue;">Marker 2</div>',
    )
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44e16c7bc88ea9f09eb641c5742f5337 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44e16c7bc88ea9f09eb641c5742f5337&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44e16c7bc88ea9f09eb641c5742f5337 = L.map(
#                 &quot;map_44e16c7bc88ea9f09eb641c5742f5337&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_540291ccfbf5ad99d9357b52fc567f6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_540291ccfbf5ad99d9357b52fc567f6a.addTo(map_44e16c7bc88ea9f09eb641c5742f5337);
#
#
#             var marker_48cb22629ccad5ea0bdd99d74b90012c = L.marker(
#                 [40.0, -100.0],
#                 {
# }
#             ).addTo(map_44e16c7bc88ea9f09eb641c5742f5337);
#
#
#             var div_icon_77b71f71c71d180897e3f278fd45a84c = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: red;\&quot;\u003eMarker 1\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_48cb22629ccad5ea0bdd99d74b90012c.setIcon(div_icon_77b71f71c71d180897e3f278fd45a84c);
#
#
#                 marker_48cb22629ccad5ea0bdd99d74b90012c.setIcon(div_icon_77b71f71c71d180897e3f278fd45a84c);
#
#
#             var marker_80cd178dd3b79f905ef09c0d909abb79 = L.marker(
#                 [41.0, -101.0],
#                 {
# }
#             ).addTo(map_44e16c7bc88ea9f09eb641c5742f5337);
#
#
#             var div_icon_14f640ec991d17a7f2e2b69fe164a9e0 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: blue;\&quot;\u003eMarker 2\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_80cd178dd3b79f905ef09c0d909abb79.setIcon(div_icon_14f640ec991d17a7f2e2b69fe164a9e0);
#
#
#                 marker_80cd178dd3b79f905ef09c0d909abb79.setIcon(div_icon_14f640ec991d17a7f2e2b69fe164a9e0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Sample data with overlapping points
data = [
    {"lat": 40, "lon": -100, "info": "Point A"},
    {"lat": 40, "lon": -100, "info": "Point B"},
    {"lat": 41, "lon": -101, "info": "Point C"},
]

# Combine data for overlapping coordinates
from collections import defaultdict
grouped = defaultdict(list)
for item in data:
    key = (item["lat"], item["lon"])
    grouped[key].append(item["info"])

m = folium.Map(location=[40, -100], zoom_start=5)

# Add combined tooltips
for (lat, lon), infos in grouped.items():
    tooltip_text = "<br>".join(infos)
    folium.Marker(
        location=[lat, lon],
        tooltip=tooltip_text
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c396bd541d1d50b222a68418174eaf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c396bd541d1d50b222a68418174eaf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c396bd541d1d50b222a68418174eaf0 = L.map(
#                 &quot;map_0c396bd541d1d50b222a68418174eaf0&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7750efe1c38bda68f35ff19890316ca6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7750efe1c38bda68f35ff19890316ca6.addTo(map_0c396bd541d1d50b222a68418174eaf0);
#
#
#             var marker_4f16c9a189d46ec07ab73c12ccd1dc9a = L.marker(
#                 [40.0, -100.0],
#                 {
# }
#             ).addTo(map_0c396bd541d1d50b222a68418174eaf0);
#
#
#             marker_4f16c9a189d46ec07ab73c12ccd1dc9a.bindTooltip(
#                 `&lt;div&gt;
#                      Point A&lt;br&gt;Point B
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_70367d2f0dce15398b552e3b93a58698 = L.marker(
#                 [41.0, -101.0],
#                 {
# }
#             ).addTo(map_0c396bd541d1d50b222a68418174eaf0);
#
#
#             marker_70367d2f0dce15398b552e3b93a58698.bindTooltip(
#                 `&lt;div&gt;
#                      Point C
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from folium.features import DivIcon

# Sample data with overlapping coordinates
data = [
    {"lat": 40, "lon": -100, "info": "Point A"},
    {"lat": 40, "lon": -100, "info": "Point B"},
    {"lat": 41, "lon": -101, "info": "Point C"},
]

# Create map
m = folium.Map(location=[40.5, -100.5], zoom_start=5)

# Add markers with unique classes and data attributes
for i, point in enumerate(data):
    marker_html = f"""
    <div class="custom-marker" 
         data-info="{point['info']}" 
         data-lat="{point['lat']}" 
         data-lon="{point['lon']}" 
         style="width: 12px; height: 12px; background: blue; border-radius: 50%; border: 2px solid white;">
    </div>
    """
    folium.Marker(
        location=[point['lat'], point['lon']],
        icon=DivIcon(html=marker_html, icon_size=(12, 12), icon_anchor=(6, 6)),
    ).add_to(m)

# Hover panel and JavaScript logic
hover_html = """
<div id="hoverPanel" style="
    position: fixed;
    bottom: 60px;
    left: 60px;
    z-index: 9999;
    background-color: white;
    border: 2px solid #555;
    border-radius: 8px;
    padding: 10px;
    box-shadow: 2px 2px 5px rgba(0,0,0,0.3);
    display: none;
    min-width: 150px;
    font-family: sans-serif;
    font-size: 14px;">
</div>

<script>
setTimeout(() => {
    const panel = document.getElementById("hoverPanel");
    const markers = document.querySelectorAll(".custom-marker");

    markers.forEach(marker => {
        marker.addEventListener("mouseenter", () => {
            const info = marker.dataset.info;
            const lat = marker.dataset.lat;
            const lon = marker.dataset.lon;

            panel.innerHTML = `<b>${info}</b><br><small>Lat: ${lat}, Lon: ${lon}</small>`;
            panel.style.display = "block";
        });

        marker.addEventListener("mouseleave", () => {
            panel.style.display = "none";
        });
    });
}, 500);
</script>
"""

m.get_root().html.add_child(folium.Element(hover_html))
m.save("hover_panel_map.html")

# %%
import folium
from folium.features import DivIcon

# Sample data with overlapping coordinates
data = [
    {"lat": 40, "lon": -100, "info": "Point A"},
    {"lat": 40, "lon": -100, "info": "Point B"},
    {"lat": 41, "lon": -101, "info": "Point C"},
]

# Create map
m = folium.Map(location=[40.5, -100.5], zoom_start=5)

# Add markers with data attributes
for i, point in enumerate(data):
    marker_html = f"""
    <div class="custom-marker" 
         data-info="{point['info']}" 
         data-lat="{point['lat']}" 
         data-lon="{point['lon']}" 
         style="width: 12px; height: 12px; background: blue; border-radius: 50%; border: 2px solid white;">
    </div>
    """
    folium.Marker(
        location=[point['lat'], point['lon']],
        icon=DivIcon(html=marker_html, icon_size=(12, 12), icon_anchor=(6, 6)),
    ).add_to(m)

# Hover panel and JavaScript
hover_panel_html = """
<div id="hoverPanel" style="
    position: fixed;
    bottom: 60px;
    left: 60px;
    z-index: 9999;
    background-color: white;
    border: 2px solid #555;
    border-radius: 8px;
    padding: 10px;
    box-shadow: 2px 2px 5px rgba(0,0,0,0.3);
    display: none;
    min-width: 150px;
    font-family: sans-serif;
    font-size: 14px;">
</div>

<script>
setTimeout(() => {
    const panel = document.getElementById("hoverPanel");
    const markers = document.querySelectorAll(".custom-marker");

    markers.forEach(marker => {
        marker.addEventListener("mouseenter", () => {
            const lat = marker.dataset.lat;
            const lon = marker.dataset.lon;

            // Find all markers at the same lat/lon
            const overlapping = Array.from(markers).filter(m =>
                m.dataset.lat === lat && m.dataset.lon === lon
            );

            // Build content
            let html = `<b>Location:</b> ${lat}, ${lon}<br><br>`;
            overlapping.forEach((m, i) => {
                html += `• ${m.dataset.info}<br>`;
            });

            panel.innerHTML = html;
            panel.style.display = "block";
        });

        marker.addEventListener("mouseleave", () => {
            panel.style.display = "none";
        });
    });
}, 500);
</script>
"""

# Inject HTML + JS into the map
m.get_root().html.add_child(folium.Element(hover_panel_html))

# Save to file
m.save("hover_panel_map.html")

# %%
import folium
from folium.features import DivIcon

# Sample data with overlapping coordinates
data = [
    {"lat": 40, "lon": -100, "info": "Point A"},
    {"lat": 40, "lon": -100, "info": "Point B"},
    {"lat": 41, "lon": -101, "info": "Point C"},
]

# Create the map
m = folium.Map(location=[40.5, -100.5], zoom_start=5)

# Add markers as div icons with data attributes
for point in data:
    marker_html = f"""
    <div class="custom-marker"
         data-info="{point['info']}"
         data-lat="{point['lat']}"
         data-lon="{point['lon']}"
         style="width: 12px; height: 12px; background: blue; border-radius: 50%; border: 2px solid white;">
    </div>
    """
    folium.Marker(
        location=[point["lat"], point["lon"]],
        icon=DivIcon(html=marker_html, icon_size=(12, 12), icon_anchor=(6, 6)),
    ).add_to(m)

# Hover panel and JS that follows the mouse
hover_panel_html = """
<div id="hoverPanel" style="
    position: fixed;
    top: 0px;
    left: 0px;
    z-index: 9999;
    background-color: white;
    border: 2px solid #555;
    border-radius: 8px;
    padding: 10px;
    box-shadow: 2px 2px 5px rgba(0,0,0,0.3);
    display: none;
    pointer-events: none;
    min-width: 150px;
    font-family: sans-serif;
    font-size: 14px;">
</div>

<script>
setTimeout(() => {
    const panel = document.getElementById("hoverPanel");
    const markers = document.querySelectorAll(".custom-marker");

    // Move panel with mouse
    document.addEventListener("mousemove", (e) => {
        panel.style.left = (e.clientX + 15) + "px";
        panel.style.top = (e.clientY + 15) + "px";
    });

    markers.forEach(marker => {
        marker.addEventListener("mouseenter", () => {
            const lat = marker.dataset.lat;
            const lon = marker.dataset.lon;

            // Find all markers at this lat/lon
            const overlapping = Array.from(markers).filter(m =>
                m.dataset.lat === lat && m.dataset.lon === lon
            );

            let html = `<b>Location:</b> ${lat}, ${lon}<br><br>`;
            overlapping.forEach(m => {
                html += `• ${m.dataset.info}<br>`;
            });

            panel.innerHTML = html;
            panel.style.display = "block";
        });

        marker.addEventListener("mouseleave", () => {
            panel.style.display = "none";
        });
    });
}, 500);
</script>
"""

# Inject the floating panel and JS
m.get_root().html.add_child(folium.Element(hover_panel_html))

# Save to file
m.save("hover_panel_map.html")
